# %% [markdown]
# # Load points

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
from numpy import *

# %%
def readstl(name): 
    STLfile = name
    f=open(STLfile,'r')

    x=[]
    y=[]
    z=[]

    for line in f:
        strarray=line.split()
        if strarray[0]=='vertex':
            x=append(x,double(strarray[1]))
            y=append(y,double(strarray[2]))
            z=append(z,double(strarray[3]))
    
    
    # calculate middle point in every triangle
    xnew = []
    ynew = []
    znew = []

    for i in range(0,len(x),3):
        xnew.append(sum(x[i:i+3])/3)
        ynew.append(sum(y[i:i+3])/3)
        znew.append(sum(z[i:i+3])/3)
    
    print('# of Sample points in %s:' %name, len(xnew))
    
    point = []
    for i in range(len(xnew)):
        point.append([xnew[i],ynew[i],znew[i]])
        
    return point

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(xnew, ynew, znew, '.')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# # Calculate shape bins

# %%
import numpy as np
def shape_bins(points):
    
    print('Calculating bins')
    
    N = len(points)
    bins_all = []
    theta_Block = 12
    phi_Block = 6
    dis_Block = 5
    for point_o in points[:]:
        distances = []
        theta = []
        phi = []
        for point in points[:]:
            distance = np.sqrt((point_o[0] - point[0]) ** 2 + (point_o[1] - point[1]) ** 2 + \
                               (point_o[2] - point[2]) ** 2 )
            if distance != 0:
                distances.append(distance)
                part_distance = np.sqrt((point[0] - point_o[0]) ** 2 + (point[1] - point_o[1]) ** 2)
                
                angl = np.arccos(np.abs(point[0] - point_o[0]) / part_distance)
                
                if point[1] - point_o[1] < 0 and point[0] - point_o[0] < 0:
                    angl = angl + np.pi
                elif point[1] - point_o[1] < 0 and point[0] - point_o[0] > 0:
                    angl = np.pi * 2 - angl
                elif point[1] - point_o[1] > 0 and point[0] - point_o[0] < 0:
                    angl = angl + np.pi / 2
                theta.append(angl)  
                
                phiangl = np.arccos(part_distance / distance)
                
                if point[2] - point_o[2] < 0:
                    phiangl = -1 * angl
                
                phi.append(phiangl)  
                
        mean_dist = np.mean(distances)
        distances = distances / mean_dist

        block_lens = 0.5
        distances_log = np.log(distances / block_lens)

        for x in range(len(distances_log)):
            if distances_log[x] <= 0:
                distances_log[x] = 0
            elif distances_log[x] <= 1:
                distances_log[x] = 1
            elif distances_log[x] <= 2:
                distances_log[x] = 2
            elif distances_log[x] <= 3:
                distances_log[x] = 3
            elif distances_log[x] <= 4:
                distances_log[x] = 4
        
        for x in range(len(phi)):
            if -np.pi/2 <= phi[x] <= -np.pi/3:
                phi[x] = 0
            elif -np.pi/3 < phi[x] <= -np.pi/6:
                phi[x] = 1
            elif -np.pi/6 < phi[x] <= 0:
                phi[x] = 2
            elif 0 < phi[x] <= np.pi/6:
                phi[x] = 3
            elif np.pi/6 < phi[x] <= np.pi/3:
                phi[x] = 4
            elif np.pi/3 < phi[x] <= np.pi/2:
                phi[x] = 5
                
        for x in range(len(theta)):
            if 0 < theta[x] <= np.pi/6:
                theta[x] = 0
            elif np.pi/6 < theta[x] <= np.pi/3:
                theta[x] = 1
            elif np.pi/3 < theta[x] <= np.pi/2:
                theta[x] = 2
            elif np.pi/2 < theta[x] <= 2*np.pi/3:
                theta[x] = 3
            elif 2*np.pi/3 < theta[x] <= 5*np.pi/6:
                theta[x] = 4
            elif 5*np.pi/6 < theta[x] <= np.pi:
                theta[x] = 5
            elif np.pi < theta[x] <= 7*np.pi/6:
                theta[x] = 6
            elif 7*np.pi/6 < theta[x] <= 4*np.pi/3:
                theta[x] = 7
            elif 4*np.pi/3 < theta[x] <= 3*np.pi/2:
                theta[x] = 8
            elif 3*np.pi/2 < theta[x] <= 5*np.pi/3:
                theta[x] = 9
            elif 5*np.pi/3 < theta[x] <= 11*np.pi/6:
                theta[x] = 10
            elif 11*np.pi/6 < theta[x] <= 2*np.pi:
                theta[x] = 11

        bins = np.zeros((dis_Block, theta_Block, phi_Block))
        for x in range(len(distances_log)):
            bins[int(distances_log[x]), int(theta[x]), int(phi[x])] =  \
            bins[int(distances_log[x]), int(theta[x]), int(phi[x])] + 1
            
        bins = np.reshape(bins,[phi_Block*theta_Block*dis_Block])
        bins_all.append(bins)
    return bins_all

# %%
start = time.clock()

bins_all = shape_bins(point[::3])
print(bins_all[0])
print(bins_all[100])
print(bins_all[1000])

end = time.clock()
print (end-start,'seconds')

# %% [markdown]
# # calculate Cost Matrix

# %%
def cost_matrix(bins_A,bins_B):
    print('Calculating cost matrix')
    
    row = 0
    col = 0
    cost = np.zeros((len(bins_A), len(bins_B)))
    for bin_A in bins_A:
        col = 0
        for bin_B in bins_B:
            cost[row, col] = 0.5 * np.sum(((bin_A - bin_B) ** 2) / (bin_A + bin_B + 0.00000001))
            col = col + 1
        row = row + 1

    return cost

# %% [markdown]
# # Munkres to find minimum

# %%
import copy
from munkres import Munkres

# %%
def cal_munkres(cost_matrix):
    matrix = copy.deepcopy(cost_matrix)
    m = Munkres()
    indexes = m.compute(matrix)
    total = 0
    
    for row, column in indexes:
        value = cost_matrix[row][column]
        total += value

    print ('minimum cost =%d' % total)
    return total

# %% [markdown]
# # Main function

# %%
from sklearn.utils import resample

# %%
result = []


for i in range(1,6):  
    cur = []  
    for j in range(1,6):
        
        point1 = readstl('S%d.stl'%i)[::100]
        point2 = readstl('G%d.stl'%j)[::100]

        if len(point1) > len(point2):
            point2 = resample(point2, replace=True, n_samples=len(point1),random_state=123)
        elif len(point1) < len(point2):
            point1 = resample(point1, replace=True, n_samples=len(point2),random_state=123)

        print('resample points to ',len(point1))


        bin1 = shape_bins(point1)
        bin2 = shape_bins(point2)

        cost = cost_matrix(bin1,bin2)

        total = cal_munkres(cost)
        
        cur.append(total)

        print('---------------------')
    
    result.append(np.mean(cur))
# Out:
# # of Sample points in S1.stl: 7558
# # of Sample points in G1.stl: 2934
# resample points to  76
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =3127
# ---------------------
# # of Sample points in S1.stl: 7558
# # of Sample points in G2.stl: 12580
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =5778
# ---------------------
# # of Sample points in S1.stl: 7558
# # of Sample points in G3.stl: 11040
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =5024
# ---------------------
# # of Sample points in S1.stl: 7558
# # of Sample points in G4.stl: 1910
# resample points to  76
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =3061
# ---------------------
# # of Sample points in S1.stl: 7558
# # of Sample points in G5.stl: 900
# resample points to  76
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =3286
# ---------------------
# # of Sample points in S2.stl: 14896
# # of Sample points in G1.stl: 2934
# resample points to  149
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =10805
# ---------------------
# # of Sample points in S2.stl: 14896
# # of Sample points in G2.stl: 12580
# resample points to  149
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =5341
# ---------------------
# # of Sample points in S2.stl: 14896
# # of Sample points in G3.stl: 11040
# resample points to  149
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =7407
# ---------------------
# # of Sample points in S2.stl: 14896
# # of Sample points in G4.stl: 1910
# resample points to  149
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =11226
# ---------------------
# # of Sample points in S2.stl: 14896
# # of Sample points in G5.stl: 900
# resample points to  149
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =12299
# ---------------------
# # of Sample points in S3.stl: 806
# # of Sample points in G1.stl: 2934
# resample points to  30
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =621
# ---------------------
# # of Sample points in S3.stl: 806
# # of Sample points in G2.stl: 12580
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =9888
# ---------------------
# # of Sample points in S3.stl: 806
# # of Sample points in G3.stl: 11040
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =7475
# ---------------------
# # of Sample points in S3.stl: 806
# # of Sample points in G4.stl: 1910
# resample points to  20
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =257
# ---------------------
# # of Sample points in S3.stl: 806
# # of Sample points in G5.stl: 900
# resample points to  9
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =53
# ---------------------
# # of Sample points in S4.stl: 2164
# # of Sample points in G1.stl: 2934
# resample points to  30
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =544
# ---------------------
# # of Sample points in S4.stl: 2164
# # of Sample points in G2.stl: 12580
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =7066
# ---------------------
# # of Sample points in S4.stl: 2164
# # of Sample points in G3.stl: 11040
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =6171
# ---------------------
# # of Sample points in S4.stl: 2164
# # of Sample points in G4.stl: 1910
# resample points to  22
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =309
# ---------------------
# # of Sample points in S4.stl: 2164
# # of Sample points in G5.stl: 900
# resample points to  22
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =316
# ---------------------
# # of Sample points in S5.stl: 706
# # of Sample points in G1.stl: 2934
# resample points to  30
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =556
# ---------------------
# # of Sample points in S5.stl: 706
# # of Sample points in G2.stl: 12580
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =9631
# ---------------------
# # of Sample points in S5.stl: 706
# # of Sample points in G3.stl: 11040
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =7750
# ---------------------
# # of Sample points in S5.stl: 706
# # of Sample points in G4.stl: 1910
# resample points to  20
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =248
# ---------------------
# # of Sample points in S5.stl: 706
# # of Sample points in G5.stl: 900
# resample points to  9
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =50
# ---------------------

# %%
print(result)
plt.hist(result,bins = 10)
plt.ylabel('minimum distance')
plt.show()
# Out:
# [4055.6954414803149, 9416.3323243033265, 3659.3472780735783, 2881.5152271195298, 3647.5033541217053]

# %%
plt.plot(result)
plt.ylabel('minimum distance')
plt.ylim(0,max(result)*1.5)
 
plt.show()

# %%
result2 = []


for i in range(1,6):  
    cur = []  
    for j in range(1,6):
        
        point1 = readstl('G%d.stl'%i)[::100]
        point2 = readstl('G%d.stl'%j)[::100]

        if len(point1) > len(point2):
            point2 = resample(point2, replace=True, n_samples=len(point1),random_state=123)
        elif len(point1) < len(point2):
            point1 = resample(point1, replace=True, n_samples=len(point2),random_state=123)

        print('resample points to ',len(point1))


        bin1 = shape_bins(point1)
        bin2 = shape_bins(point2)

        cost = cost_matrix(bin1,bin2)

        total = cal_munkres(cost)
        
        cur.append(total)

        print('---------------------')
    
    result2.append(np.mean(cur))
# Out:
# # of Sample points in G1.stl: 2934
# # of Sample points in G1.stl: 2934
# resample points to  30
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =0
# ---------------------
# # of Sample points in G1.stl: 2934
# # of Sample points in G2.stl: 12580
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =8148
# ---------------------
# # of Sample points in G1.stl: 2934
# # of Sample points in G3.stl: 11040
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =5826
# ---------------------
# # of Sample points in G1.stl: 2934
# # of Sample points in G4.stl: 1910
# resample points to  30
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =556
# ---------------------
# # of Sample points in G1.stl: 2934
# # of Sample points in G5.stl: 900
# resample points to  30
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =566
# ---------------------
# # of Sample points in G2.stl: 12580
# # of Sample points in G1.stl: 2934
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =8148
# ---------------------
# # of Sample points in G2.stl: 12580
# # of Sample points in G2.stl: 12580
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =0
# ---------------------
# # of Sample points in G2.stl: 12580
# # of Sample points in G3.stl: 11040
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =5810
# ---------------------
# # of Sample points in G2.stl: 12580
# # of Sample points in G4.stl: 1910
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =8721
# ---------------------
# # of Sample points in G2.stl: 12580
# # of Sample points in G5.stl: 900
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =8641
# ---------------------
# # of Sample points in G3.stl: 11040
# # of Sample points in G1.stl: 2934
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =5826
# ---------------------
# # of Sample points in G3.stl: 11040
# # of Sample points in G2.stl: 12580
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =5810
# ---------------------
# # of Sample points in G3.stl: 11040
# # of Sample points in G3.stl: 11040
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =0
# ---------------------
# # of Sample points in G3.stl: 11040
# # of Sample points in G4.stl: 1910
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =6604
# ---------------------
# # of Sample points in G3.stl: 11040
# # of Sample points in G5.stl: 900
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =7386
# ---------------------
# # of Sample points in G4.stl: 1910
# # of Sample points in G1.stl: 2934
# resample points to  30
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =556
# ---------------------
# # of Sample points in G4.stl: 1910
# # of Sample points in G2.stl: 12580
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =8721
# ---------------------
# # of Sample points in G4.stl: 1910
# # of Sample points in G3.stl: 11040
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =6604
# ---------------------
# # of Sample points in G4.stl: 1910
# # of Sample points in G4.stl: 1910
# resample points to  20
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =0
# ---------------------
# # of Sample points in G4.stl: 1910
# # of Sample points in G5.stl: 900
# resample points to  20
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =268
# ---------------------
# # of Sample points in G5.stl: 900
# # of Sample points in G1.stl: 2934
# resample points to  30
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =566
# ---------------------
# # of Sample points in G5.stl: 900
# # of Sample points in G2.stl: 12580
# resample points to  126
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =8641
# ---------------------
# # of Sample points in G5.stl: 900
# # of Sample points in G3.stl: 11040
# resample points to  111
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =7386
# ---------------------
# # of Sample points in G5.stl: 900
# # of Sample points in G4.stl: 1910
# resample points to  20
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =268
# ---------------------
# # of Sample points in G5.stl: 900
# # of Sample points in G5.stl: 900
# resample points to  9
# Calculating bins
# Calculating bins
# Calculating cost matrix
# minimum cost =0
# ---------------------

# %%
print(result2)
plt.hist(result2,bins = 10,cumulative=False)
plt.ylabel('minimum distance')
 
plt.show()
# Out:
# [3019.6292343223104, 6264.3708711021145, 5125.5474651653267, 3230.1209555770029, 3372.5068623292382]

# %%
plt.plot(result2)
plt.ylabel('minimum distance')
plt.ylim(0,max(result2)*1.5)
 
plt.show()
